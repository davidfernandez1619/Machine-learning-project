# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.ticker as ticker
import seaborn as sns

plt.rcParams["figure.figsize"] = (10,8)

import warnings
warnings.filterwarnings('ignore')

import pandas as pd

from sklearn.preprocessing import LabelEncoder  

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.model_selection import train_test_split


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn import metrics

# %%
df = pd.read_csv('/Users/davidfernandez/Desktop/Projects/Machine learning project/Kaggle_competition/Data/First combination/preprocessed.csv')

# %%
df
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.30    Premium     D     SI2   62.4   58.0  4.31  4.28  2.68
# 1          1   1.01      Ideal     E    VVS2   62.7   56.0  6.42  6.46  4.04
# 2          2   0.72      Ideal     F     VS2   61.8   59.0  5.71  5.74  3.54
# 3          3   1.08  Very Good     G     SI2   63.2   57.0  6.54  6.50  4.12
# 4          4   0.36    Premium     G     VS1   62.3   59.0  4.50  4.55  2.82
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 40450  40450   0.42    Premium     D     SI2   62.1   59.0  4.78  4.82  2.98
# 40451  40451   0.53    Premium     G     VS2   62.0   58.0  5.21  5.18  3.22
# 40452  40452   0.80       Good     G     SI2   62.8   58.0  5.86  5.90  3.69
# 40453  40453   1.01  Very Good     F     VS2   61.5   57.0  6.40  6.48  3.96
# 40454  40454   1.30    Premium     I     VS2   60.1   58.0  7.10  7.14  4.28
#
#        price  cut_encoded  color_encoded  clarity_encoded
# 0      6.353            1              5                0
# 1      9.183            4              6                5
# 2      7.983            4              4                3
# 3      8.371            3              3                0
# 4      6.588            1              3                4
# ...      ...          ...            ...              ...
# 40450  6.551            1              5                0
# 40451  7.382            1              3                3
# 40452  7.768            2              3                0
# 40453  8.726            3              4                3
# 40454  8.771            1              1                3
#
# [40455 rows x 14 columns]

# %% [markdown]
# ## Model adjustment

# %%
X = df.drop(['price', 'cut', 'color', 'clarity'], axis =1)

y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

# %% [markdown]
# ### Decision tree

# %%
regressor = DecisionTreeRegressor(random_state = 0) 
  
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# %time
fig = plt.figure(figsize=(10, 6))
tree.plot_tree(regressor, feature_names=X_train.columns, filled=True)
plt.show();
# Out:
# CPU times: user 2 µs, sys: 2 µs, total: 4 µs
# Wall time: 14.1 µs

# %%
# max features

max_features = np.sqrt(len(X_train.columns))
max_features
# Out:
# 3.1622776601683795

# %%
# max depth

print(regressor.tree_.max_depth)
# Out:
# 33

# %%
y_pred_test_dt = regressor.predict(X_test)
y_pred_train_dt = regressor.predict(X_train)

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    
    
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
dt_results1 = metricas(y_test, y_train, y_pred_test_dt, y_pred_train_dt, "Decission Tree I")
dt_results1
# Out:
#             MAE           MSE          RMSE        R2    set            modelo
# 0  8.840356e-02  1.606634e-02  1.267531e-01  0.984527   test  Decission Tree I
# 1  2.026200e-17  2.736018e-32  1.654091e-16  1.000000  train  Decission Tree I

# %%
param = {"max_depth": [4, 5, 6, 7],
        "min_samples_split": [10, 50, 100],
        "max_features": [1,2,3,4,5,6]}

gs = GridSearchCV(
            estimator=DecisionTreeRegressor(),
            param_grid= param,
            cv=10,
            verbose=3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

# %%
# %time
gs.fit(X_train, y_train)
# Out:
# CPU times: user 4 µs, sys: 11 µs, total: 15 µs
# Wall time: 65.1 µs
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.523, test=-0.527) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.828, test=-0.840) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.500, test=-0.508) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-1.012, test=-1.011) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.164, test=-0.175) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.215, test=-0.207) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.125, test=-0.129) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.152, test=-0.152) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.153, test=-0.143) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=10;, score=(train=-0.345, test=-0.334) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.191, test=-0.192) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.125, test=-0.130) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.116, test=-0.112) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.127, test=-0.131) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.654, test=-0.665) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.215, test=-0.203) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.197, test=-0.202) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.165, test=-0.167) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.195, test=-0.194) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=50;, score=(train=-0.194, test=-0.198) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.127, test=-0.130) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.248, test=-0.256) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.488, test=-0.486) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.384, test=-0.382) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.191, test=-0.206) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.531, test=-0.512) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.410, test=-0.428) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.443, test=-0.423) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.114, test=-0.113) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=1, min_samples_split=100;, score=(train=-0.891, test=-0.914) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.125, test=-0.123) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.069, test=-0.071) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.112, test=-0.110) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.110, test=-0.108) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.111, test=-0.111) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.180, test=-0.170) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.163, test=-0.168) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.065, test=-0.065) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.059, test=-0.058) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=10;, score=(train=-0.071, test=-0.072) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.069, test=-0.072) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.062, test=-0.065) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.090, test=-0.092) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.078, test=-0.076) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.068, test=-0.069) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.103, test=-0.112) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.073, test=-0.071) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.117, test=-0.115) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.230, test=-0.226) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=50;, score=(train=-0.066, test=-0.067) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.075, test=-0.077) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.119, test=-0.125) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.065, test=-0.065) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.066, test=-0.062) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.101, test=-0.102) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.064, test=-0.065) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.092, test=-0.096) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.134, test=-0.137) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.180, test=-0.175) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=2, min_samples_split=100;, score=(train=-0.070, test=-0.069) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.057, test=-0.058) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.058, test=-0.061) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.122, test=-0.124) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.071, test=-0.068) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.059, test=-0.060) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.061, test=-0.062) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.062, test=-0.064) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.062, test=-0.061) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.134, test=-0.131) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=10;, score=(train=-0.064, test=-0.066) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.056, test=-0.057) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.112, test=-0.116) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.056, test=-0.055) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.058, test=-0.056) total time=   0.0s
# [CV 5/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.066, test=-0.069) total time=   0.0s
# [CV 6/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.056, test=-0.054) total time=   0.0s
# [CV 7/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.057, test=-0.060) total time=   0.0s
# [CV 8/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.059, test=-0.058) total time=   0.0s
# [CV 9/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.062, test=-0.064) total time=   0.0s
# [CV 10/10] END max_depth=4, max_features=3, min_samples_split=50;, score=(train=-0.075, test=-0.077) total time=   0.0s
# [CV 1/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.059, test=-0.059) total time=   0.0s
# [CV 2/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.055, test=-0.059) total time=   0.0s
# [CV 3/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0.068, test=-0.068) total time=   0.0s
# [CV 4/10] END max_depth=4, max_features=3, min_samples_split=100;, score=(train=-0
10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.086, test=-0.086) total time=   0.0s
# [CV 10/10] END max_depth=6, max_features=2, min_samples_split=10;, score=(train=-0.041, test=-0.044) total time=   0.0s
# ...
# [CV 10/10] END max_depth=7, max_features=2, min_samples_split=50;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.062, test=-0.066) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.036, test=-0.038) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.044, test=-0.042) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.049, test=-0.050) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.057, test=-0.060) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.043, test=-0.047) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.050, test=-0.053) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.042, test=-0.043) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=2, min_samples_split=100;, score=(train=-0.039, test=-0.043) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.037, test=-0.039) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.037, test=-0.038) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.038, test=-0.038) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.035, test=-0.038) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.037, test=-0.040) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.041, test=-0.042) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.041, test=-0.043) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=10;, score=(train=-0.031, test=-0.035) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.031, test=-0.033) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.035, test=-0.036) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.035, test=-0.038) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.048, test=-0.047) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.040, test=-0.041) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.034, test=-0.038) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.031, test=-0.034) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.033, test=-0.033) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.032, test=-0.032) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=50;, score=(train=-0.038, test=-0.040) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.040, test=-0.043) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.037, test=-0.040) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.036, test=-0.038) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.038, test=-0.039) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.039, test=-0.041) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.041, test=-0.044) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.042, test=-0.045) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.036, test=-0.039) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.034, test=-0.036) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=3, min_samples_split=100;, score=(train=-0.033, test=-0.034) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.035, test=-0.038) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.030, test=-0.029) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.035, test=-0.037) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.031, test=-0.032) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.038, test=-0.037) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=10;, score=(train=-0.032, test=-0.035) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.033) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.033, test=-0.035) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.036, test=-0.036) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.034, test=-0.036) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.028, test=-0.028) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.031, test=-0.033) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=50;, score=(train=-0.031, test=-0.035) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.033, test=-0.036) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.032, test=-0.032) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.032, test=-0.034) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.032, test=-0.032) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=4, min_samples_split=100;, score=(train=-0.031, test=-0.034) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.028, test=-0.032) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.026, test=-0.029) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.031, test=-0.033) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.029, test=-0.030) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=10;, score=(train=-0.026, test=-0.029) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.028, test=-0.029) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.028, test=-0.031) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.036, test=-0.038) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.026, test=-0.029) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=50;, score=(train=-0.038, test=-0.042) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.030, test=-0.032) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.030, test=-0.030) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.029, test=-0.031) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.029, test=-0.029) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.031, test=-0.031) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.031, test=-0.033) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=5, min_samples_split=100;, score=(train=-0.028, test=-0.032) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.025, test=-0.028) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.027, test=-0.029) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.026, test=-0.029) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.027) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.024) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.028, test=-0.030) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.027, test=-0.028) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=10;, score=(train=-0.024, test=-0.027) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.025) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.026, test=-0.027) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.027) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.024, test=-0.024) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.025, test=-0.025) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=50;, score=(train=-0.027, test=-0.030) total time=   0.0s
# [CV 1/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.032, test=-0.035) total time=   0.0s
# [CV 2/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.026, test=-0.028) total time=   0.0s
# [CV 3/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.025, test=-0.026) total time=   0.0s
# [CV 4/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.024, test=-0.024) total time=   0.0s
# [CV 5/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 6/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.030, test=-0.031) total time=   0.0s
# [CV 7/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.028, test=-0.029) total time=   0.0s
# [CV 8/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 9/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.025, test=-0.027) total time=   0.0s
# [CV 10/10] END max_depth=7, max_features=6, min_samples_split=100;, score=(train=-0.027, test=-0.030) total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7],
#                          'max_features': [1, 2, 3, 4, 5, 6],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %%
best_tree = gs.best_estimator_
best_tree
# Out:
# DecisionTreeRegressor(max_depth=7, max_features=6, min_samples_split=50)

# %%
fig = plt.figure(figsize=(12, 6))
tree.plot_tree(best_tree, feature_names=X_train.columns, filled=True);

# %%
fig.savefig("decision_tree.png", facecolor="white")

# %%
print(tree.export_text(best_tree, feature_names= list(X_train.columns)))
# Out:
# |--- y <= 5.64
# |   |--- carat <= 0.45
# |   |   |--- x <= 4.61
# |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |--- z <= 2.59
# |   |   |   |   |   |--- x <= 4.10
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [6.06]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [6.28]
# |   |   |   |   |   |--- x >  4.10
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [6.20]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [6.38]
# |   |   |   |   |--- z >  2.59
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [6.22]
# |   |   |   |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [6.39]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- x <= 4.36
# |   |   |   |   |   |   |   |--- value: [6.47]
# |   |   |   |   |   |   |--- x >  4.36
# |   |   |   |   |   |   |   |--- value: [6.60]
# |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |--- carat <= 0.30
# |   |   |   |   |   |--- carat <= 0.25
# |   |   |   |   |   |   |--- cut_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.48]
# |   |   |   |   |   |   |--- cut_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [6.26]
# |   |   |   |   |   |--- carat >  0.25
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [6.37]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [6.51]
# |   |   |   |   |--- carat >  0.30
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.49]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [6.69]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- x <= 4.45
# |   |   |   |   |   |   |   |--- value: [6.81]
# |   |   |   |   |   |   |--- x >  4.45
# |   |   |   |   |   |   |   |--- value: [6.94]
# |   |   |--- x >  4.61
# |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |--- x <= 4.71
# |   |   |   |   |   |--- y <= 4.64
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.46]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [6.76]
# |   |   |   |   |   |--- y >  4.64
# |   |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [6.53]
# |   |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [6.69]
# |   |   |   |   |--- x >  4.71
# |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [6.61]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [6.73]
# |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |--- cut_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.89]
# |   |   |   |   |   |   |--- cut_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [6.81]
# |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |   |--- value: [6.53]
# |   |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |   |--- value: [6.73]
# |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |--- x <= 4.67
# |   |   |   |   |   |   |   |--- value: [6.63]
# |   |   |   |   |   |   |--- x >  4.67
# |   |   |   |   |   |   |   |--- value: [6.81]
# |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |--- clarity_encoded <= 5.50
# |   |   |   |   |   |   |--- x <= 4.76
# |   |   |   |   |   |   |   |--- value: [6.89]
# |   |   |   |   |   |   |--- x >  4.76
# |   |   |   |   |   |   |   |--- value: [6.99]
# |   |   |   |   |   |--- clarity_encoded >  5.50
# |   |   |   |   |   |   |--- carat <= 0.39
# |   |   |   |   |   |   |   |--- value: [7.05]
# |   |   |   |   |   |   |--- carat >  0.39
# |   |   |   |   |   |   |   |--- value: [7.14]
# |   |--- carat >  0.45
# |   |   |--- clarity_encoded <= 2.50
# |   |   |   |--- carat <= 0.62
# |   |   |   |   |--- carat <= 0.53
# |   |   |   |   |   |--- x <= 5.05
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [6.82]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.02]
# |   |   |   |   |   |--- x >  5.05
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.03]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.19]
# |   |   |   |   |--- carat >  0.53
# |   |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.10]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.23]
# |   |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.20]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.43]
# |   |   |   |--- carat >  0.62
# |   |   |   |   |--- color_encoded <= 4.50
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- depth <= 66.05
# |   |   |   |   |   |   |   |--- value: [7.45]
# |   |   |   |   |   |   |--- depth >  66.05
# |   |   |   |   |   |   |   |--- value: [7.05]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- z <= 3.47
# |   |   |   |   |   |   |   |--- value: [7.44]
# |   |   |   |   |   |   |--- z >  3.47
# |   |   |   |   |   |   |   |--- value: [7.66]
# |   |   |   |   |--- color_encoded >  4.50
# |   |   |   |   |   |--- carat <= 0.69
# |   |   |   |   |   |   |--- value: [7.51]
# |   |   |   |   |   |--- carat >  0.69
# |   |   |   |   |   |   |--- z <= 3.67
# |   |   |   |   |   |   |   |--- value: [7.75]
# |   |   |   |   |   |   |--- z >  3.67
# |   |   |   |   |   |   |   |--- value: [7.38]
# |   |   |--- clarity_encoded >  2.50
# |   |   |   |--- y <= 5.42
# |   |   |   |   |--- x <= 5.11
# |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.06]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.35]
# |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |--- carat <= 0.48
# |   |   |   |   |   |   |   |--- value: [7.35]
# |   |   |   |   |   |   |--- carat >  0.48
# |   |   |   |   |   |   |   |--- value: [7.56]
# |   |   |   |   |--- x >  5.11
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- x <= 6.10
# |   |   |   |   |   |   |   |--- value: [7.33]
# |   |   |   |   |   |   |--- x >  6.10
# |   |   |   |   |   |   |   |--- value: [8.72]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |   |--- value: [7.49]
# |   |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |   |--- value: [7.73]
# |   |   |   |--- y >  5.42
# |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |--- carat <= 0.69
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.26]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.63]
# |   |   |   |   |   |--- carat >  0.69
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.68]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.89]
# |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.67]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [7.86]
# |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |--- z <= 3.31
# |   |   |   |   |   |   |   |--- value: [7.90]
# |   |   |   |   |   |   |--- z >  3.31
# |   |   |   |   |   |   |   |--- value: [8.07]
# |--- y >  5.64
# |   |--- y <= 6.82
# |   |   |--- y <= 6.14
# |   |   |   |--- y <= 5.93
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [7.56]
# |   |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.73]
# |   |   |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.78]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.97]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.74]
# |   |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [7.87]
# |   |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |   |--- cut_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [8.01]
# |   |   |   |   |   |   |--- cut_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [8.11]
# |   |   |   |--- y >  5.93
# |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |--- carat <= 0.88
# |   |   |   |   |   |   |   |--- value: [7.88]
# |   |   |   |   |   |   |--- carat >  0.88
# |   |   |   |   |   |   |   |--- value: [8.09]
# |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |--- value: [7.59]
# |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |--- carat <= 0.87
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [7.91]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [8.15]
# |   |   |   |   |   |--- carat >  0.87
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.07]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.31]
# |   |   |--- y >  6.14
# |   |   |   |--- carat <= 0.99
# |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- value: [7.96]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [8.21]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [7.80]
# |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- z <= 3.62
# |   |   |   |   |   |   |   |--- value: [7.64]
# |   |   |   |   |   |   |--- z >  3.62
# |   |   |   |   |   |   |   |--- value: [8.16]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [8.36]
# |   |   |   |   |   |   |--- clarity_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [8.52]
# |   |   |   |--- carat >  0.99
# |   |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |   |--- y <= 6.65
# |   |   |   |   |   |   |--- carat <= 1.65
# |   |   |   |   |   |   |   |--- value: [8.41]
# |   |   |   |   |   |   |--- carat >  1.65
# |   |   |   |   |   |   |   |--- value: [9.76]
# |   |   |   |   |   |--- y >  6.65
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.44]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.56]
# |   |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |--- carat <= 1.05
# |   |   |   |   |   |   |   |--- value: [8.49]
# |   |   |   |   |   |   |--- carat >  1.05
# |   |   |   |   |   |   |   |--- value: [8.63]
# |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |--- y <= 6.62
# |   |   |   |   |   |   |   |--- value: [8.89]
# |   |   |   |   |   |   |--- y >  6.62
# |   |   |   |   |   |   |   |--- value: [9.06]
# |   |--- y >  6.82
# |   |   |--- y <= 7.24
# |   |   |   |--- clarity_encoded <= 2.50
# |   |   |   |   |--- carat <= 1.38
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- carat <= 1.29
# |   |   |   |   |   |   |   |--- value: [8.55]
# |   |   |   |   |   |   |--- carat >  1.29
# |   |   |   |   |   |   |   |--- value: [8.68]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [8.61]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [8.84]
# |   |   |   |   |--- carat >  1.38
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- depth <= 64.75
# |   |   |   |   |   |   |   |--- value: [8.85]
# |   |   |   |   |   |   |--- depth >  64.75
# |   |   |   |   |   |   |   |--- value: [8.62]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- y <= 7.19
# |   |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |   |   |--- y >  7.19
# |   |   |   |   |   |   |   |--- value: [9.14]
# |   |   |   |--- clarity_encoded >  2.50
# |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |--- z <= 4.43
# |   |   |   |   |   |   |   |--- value: [8.71]
# |   |   |   |   |   |   |--- z >  4.43
# |   |   |   |   |   |   |   |--- value: [8.98]
# |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |--- carat <= 1.36
# |   |   |   |   |   |   |   |--- value: [8.94]
# |   |   |   |   |   |   |--- carat >  1.36
# |   |   |   |   |   |   |   |--- value: [9.13]
# |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |--- clarity_encoded <= 4.50
# |   |   |   |   |   |   |--- x <= 7.12
# |   |   |   |   |   |   |   |--- value: [9.13]
# |   |   |   |   |   |   |--- x >  7.12
# |   |   |   |   |   |   |   |--- value: [9.37]
# |   |   |   |   |   |--- clarity_encoded >  4.50
# |   |   |   |   |   |   |--- color_encoded <= 3.50
# |   |   |   |   |   |   |   |--- value: [9.27]
# |   |   |   |   |   |   |--- color_encoded >  3.50
# |   |   |   |   |   |   |   |--- value: [9.49]
# |   |   |--- y >  7.24
# |   |   |   |--- x <= 7.85
# |   |   |   |   |--- y <= 7.57
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- clarity_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [9.01]
# |   |   |   |   |   |   |--- clarity_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [8.62]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 2.50
# |   |   |   |   |   |   |   |--- value: [9.17]
# |   |   |   |   |   |   |--- color_encoded >  2.50
# |   |   |   |   |   |   |   |--- value: [9.48]
# |   |   |   |   |--- y >  7.57
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- y <= 7.81
# |   |   |   |   |   |   |   |--- value: [9.12]
# |   |   |   |   |   |   |--- y >  7.81
# |   |   |   |   |   |   |   |--- value: [9.39]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- color_encoded <= 1.50
# |   |   |   |   |   |   |   |--- value: [9.25]
# |   |   |   |   |   |   |--- color_encoded >  1.50
# |   |   |   |   |   |   |   |--- value: [9.52]
# |   |   |   |--- x >  7.85
# |   |   |   |   |--- y <= 7.92
# |   |   |   |   |   |--- clarity_encoded <= 1.50
# |   |   |   |   |   |   |--- depth <= 63.45
# |   |   |   |   |   |   |   |--- value: [9.29]
# |   |   |   |   |   |   |--- depth >  63.45
# |   |   |   |   |   |   |   |--- value: [9.06]
# |   |   |   |   |   |--- clarity_encoded >  1.50
# |   |   |   |   |   |   |--- id <= 22302.50
# |   |   |   |   |   |   |   |--- value: [9.46]
# |   |   |   |   |   |   |--- id >  22302.50
# |   |   |   |   |   |   |   |--- value: [9.62]
# |   |   |   |   |--- y >  7.92
# |   |   |   |   |   |--- color_encoded <= 0.50
# |   |   |   |   |   |   |--- x <= 8.28
# |   |   |   |   |   |   |   |--- value: [9.44]
# |   |   |   |   |   |   |--- x >  8.28
# |   |   |   |   |   |   |   |--- value: [9.61]
# |   |   |   |   |   |--- color_encoded >  0.50
# |   |   |   |   |   |   |--- cut_encoded <= 0.50
# |   |   |   |   |   |   |   |--- value: [9.36]
# |   |   |   |   |   |   |--- cut_encoded >  0.50
# |   |   |   |   |   |   |   |--- value: [9.63]

# %% [markdown]
# ## Prediction

# %%
y_pred_test_dt2 = best_tree.predict(X_test)
y_pred_train_dt2 = best_tree.predict(X_train)

# %%
dt_results2 = metricas(y_test, y_train, y_pred_test_dt2, y_pred_train_dt2, "Decision tree II")

# %%
dt_results2
# Out:
#         MAE       MSE      RMSE        R2    set            modelo
# 0  0.127694  0.027814  0.166776  0.973213   test  Decision tree II
# 1  0.126102  0.026938  0.164127  0.973907  train  Decision tree II

# %% [markdown]
# ## Test

# %%
df1 = pd.read_csv("/Users/davidfernandez/Desktop/Projects/Machine learning project/Kaggle_competition/Data/reality.csv", index_col = 0)

# %%
df1
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.32      Ideal     I     SI1   60.5   58.0  4.43  4.49  2.70
# 1          1   1.24    Premium     I     SI1   62.9   60.0  6.80  6.74  4.26
# 2          2   1.66    Premium     D     SI1   62.0   59.0  7.55  7.60  4.70
# 3          3   0.75    Premium     D     SI2   60.6   56.0  5.94  5.90  3.59
# 4          4   1.50       Fair     E     SI2   64.8   55.0  7.26  7.15  4.67
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   1.10    Premium     G     SI1   59.6   60.0  6.74  6.70  4.00
# 13481  13481   0.90  Very Good     D     SI1   62.1   60.0  6.14  6.20  3.83
# 13482  13482   0.30      Ideal     F     VS2   62.1   53.3  4.30  4.32  2.68
# 13483  13483   1.25      Ideal     I     SI1   59.6   59.0  7.01  7.09  4.20
# 13484  13484   0.81    Premium     F     SI1   61.6   58.0  5.96  5.92  3.66
#
#        cut_encoded  color_encoded  clarity_encoded
# 0                4              1                2
# 1                1              1                2
# 2                1              5                2
# 3                1              5                0
# 4                0              6                0
# ...            ...            ...              ...
# 13480            1              3                2
# 13481            3              5                2
# 13482            4              4                3
# 13483            4              1                2
# 13484            1              4                2
#
# [13482 rows x 13 columns]

# %%
X_reality = df1.drop(['cut', 'color', 'clarity'], axis=1)

# %%
X_reality_submision = best_tree.predict(X_reality)
X_reality_submision
# Out:
# array([6.21596486, 8.43648235, 9.52320648, ..., 6.47136087, 8.61133333,
#        7.8651363 ])

# %%
submision1 = pd.DataFrame(X_reality_submision)
submision1.reset_index(inplace=True)
submision1.rename(columns={"index":"id",0:"price"}, inplace =True)
submision1
# Out:
#           id     price
# 0          0  6.215965
# 1          1  8.436482
# 2          2  9.523206
# 3          3  7.744552
# 4          4  8.618059
# ...      ...       ...
# 13477  13477  8.555215
# 13478  13478  8.362110
# 13479  13479  6.471361
# 13480  13480  8.611333
# 13481  13481  7.865136
#
# [13482 rows x 2 columns]

# %%
submision1.to_csv("submission_david1.csv", index=False)

# %%
DFF = pd.read_csv("/Users/davidfernandez/Desktop/submission_david1.csv", index_col = 0)


DFF
# Out:
#           price
# id
# 0      6.215965
# 1      8.436482
# 2      9.523206
# 3      7.744552
# 4      8.618059
# ...         ...
# 13477  8.555215
# 13478  8.362110
# 13479  6.471361
# 13480  8.611333
# 13481  7.865136
#
# [13482 rows x 1 columns]
